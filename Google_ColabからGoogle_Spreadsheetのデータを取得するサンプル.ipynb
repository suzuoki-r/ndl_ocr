# %% [markdown]
# <a href="https://colab.research.google.com/github/nakamura196/ndl_ocr/blob/main/Google_Colab%E3%81%8B%E3%82%89Google_Spreadsheet%E3%81%AE%E3%83%87%E3%83%BC%E3%82%BF%E3%82%92%E5%8F%96%E5%BE%97%E3%81%99%E3%82%8B%E3%82%B5%E3%83%B3%E3%83%97%E3%83%AB.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import auth
auth.authenticate_user()

import gspread
from google.auth import default
creds, _ = default()

gc = gspread.authorize(creds)

# %%
import pandas as pd
from pandas import json_normalize

# シートの指定
ss_id = "1qPUcLGrgGr6b80mdzO1JRmwhO2BTNgbtKCmSLT9l7lg"
workbook = gc.open_by_key(ss_id)

worksheet = workbook.get_worksheet(0)

# 全データを取得
data = worksheet.get_all_records()

df = json_normalize(data)
df
# Out:
#   dcterms:identifier        dcterms:title            dcterms:description  \
# 0            post_69  横から見たオムツ姿の赤ちゃんのイラスト   オムツだけを履いた裸の赤ちゃんを横から見たイラストです。
# 1           post_226      赤ちゃんの胸囲の測定のイラスト  赤ちゃんの胴回りをメジャーを使って測っているイラストです。
#
#   dcterms:date §private dcterms:subject @ja dcterms:subject @en  \
# 0            2020-12-17         あかちゃん|リクエスト        Baby|Request
# 1            2020-11-24            あかちゃん|医療   Baby|Medical Care
#
#                      dcterms:rights ^^uri item set resource template  public  \
# 0  https://www.irasutoya.com/p/terms.html     baby     Base Resource       1
# 1  https://www.irasutoya.com/p/terms.html     baby     Base Resource       1
#
#    owner
# 0      1
# 1      1
